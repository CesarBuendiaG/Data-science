# %%
import pandas as pd

# %% [markdown]
# En Pandas hay ods objetos core: **DataFrames** y **Series**

# %% [markdown]
# ### DataFrame
# Es una tabla, contiene una matriz de entradas individuales, cada con un valor determinado. Cada entrada corresponde a una fila(registro) y a una columna.

# %%
# pd.DataFrame() es un constructor para generar objetos DataFrame, se declara de forma diccionario (Key-Values)
# Las listas de diccionario asigna al indice un valor automatico (0,1,2,3,...) para cada registro
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %% [markdown]
# Aqui, la entrada "50" corresponde a la fila 0 y a la columna "Yes"

# %%
# Las entradas no se limitan a enteros
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
# El indice que se asigna en automatico se puede modificar el nombre
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# ### Series
# Es una secuencia de datos. **DataFrame** es una tabla
# **Series** es una lista, escencialmente es una simple _columna_ de un DataFrame

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# Puedes asignarles nombres a los registros, pero **no** puedes darle nombre a la columna, sino un nombre "general"

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# La Serie y el DataFrame están íntimamente relacionados.
# Es útil pensar en un DataFrame como un conjunto de Series "pegadas".

# %% [markdown]
# ## Leer archivos

# %%
# Haces referencia al archivo (en caso de no estar en la misma carpeta, tienes que incluir la direccion del archivo)
# "encodig" sirve para ciertos caracteres, como los acentos 
df = pd.read_csv("Data.csv",encoding='latin-1')

# %%
# *shape nos ayuda a saber el tamaño de la tabla (Filas y Columnas)
df.shape
# Out:
# (30, 7)

# %%
# *head nos ayuda a ver los primeros registros (por defecto 5, pero puedes escribir cualquier numero)
df.head()
# Out:
#    idProducto Códigos de producto  Precio                Cliente  \
# 0           0           51993Masc   $9.98  Candy's Beauty Supply
# 1           1           49631Foun  $14.49             Rockland's
# 2           2           42292Glos   $6.74       Rudiger Pharmacy
# 3           3           86661Shad   $5.71   Elizabethtown Supply
# 4           4           49541Eyel   $7.94             Rockland's
#
#   Código de cliente  Pedidos      Total
# 0          PINNC980      191  $1,906.18
# 1          ARLVA283      152  $2,202.48
# 2          CHEMD763      758  $5,108.92
# 3          COLSC761      308  $1,758.68
# 4          ARLVA425       50    $397.00

# %% [markdown]
# En este caso podemos ver que la tabla tiene sus propios indices, los cuales no los toma automaticamente, para hacer que los tome puedes definir cual va a aser el indice

# %%
# Aqui le decimos que la columna 0 (idProducto) va a ser el indice de la tabla (columna indice)
dfc = pd.read_csv("Data.csv",encoding='latin-1', index_col=0)
dfc
# Out:
#            Códigos de producto  Precio                Cliente  \
# idProducto
# 0                    51993Masc   $9.98  Candy's Beauty Supply
# 1                    49631Foun  $14.49             Rockland's
# 2                    42292Glos   $6.74       Rudiger Pharmacy
# 3                    86661Shad   $5.71   Elizabethtown Supply
# 4                    49541Eyel   $7.94             Rockland's
# 5                    58337Foun  $13.57  Candy's Beauty Supply
# 6                    40014Masc   $8.46   Elizabethtown Supply
# 7                    86139Lips   $5.55  Candy's Beauty Supply
# 8                    69601Exfo  $11.05             Rockland's
# 9                    25331Glos   $7.58             Rockland's
# 10                   85021Foun  $11.75       Rudiger Pharmacy
# 11                   69030Masc  $10.95   Elizabethtown Supply
# 12                   13230Masc  $11.73             Rockland's
# 13                   91559Eyel   $6.66  Candy's Beauty Supply
# 14                   62289Masc  $12.06   Elizabethtown Supply
# 15                   64762Foun  $12.95       Rudiger Pharmacy
# 16                   52341Foun  $13.09   Elizabethtown Supply
# 17                   68713Exfo  $15.77             Rockland's
# 18                   35073Foun  $11.82   Elizabethtown Supply
# 19                   17691Masc  $11.22   Elizabethtown Supply
# 20                   03485Eyel   $7.00       Rudiger Pharmacy
# 21                   26156Foun  $12.01  Candy's Beauty Supply
# 22                   75112Foun  $13.24   Elizabethtown Supply
# 23                   96799Foun  $10.07       Rudiger Pharmacy
# 24                   20559Shad   $4.33   Elizabethtown Supply
# 25                   32729Masc  $13.13   Elizabethtown Supply
# 26                   63094Exfo  $16.94  Candy's Beauty Supply
# 27                   61207Foun   $9.83       Rudiger Pharmacy
# 28                   17269Masc  $14.95             Rockland's
# 29                   15143Exfo  $20.04       Rudiger Pharmacy
#
#            Código de cliente  Pedidos       Total
# idProducto
# 0                   PINNC980      191   $1,906.18
# 1                   ARLVA283      152   $2,202.48
# 2                   CHEMD763      758   $5,108.92
# 3                   COLSC761      308   $1,758.68
# 4                   ARLVA425       50     $397.00
# 5                   PINNC939      673   $9,132.61
# 6                   COLSC649       94     $795.24
# 7                   PINNC496      299   $1,659.45
# 8                   ARLVA851      850   $9,392.50
# 9                   ARLVA924      169   $1,281.02
# 10                  CHEMD339      707   $8,307.25
# 11                  COLSC970      461   $5,047.95
# 12                  ARLVA519       78     $914.94
# 13                  PINNC674      444   $2,957.04
# 14                  COLSC887      797   $9,611.82
# 15                  CHEMD913      355   $4,597.25
# 16                  COLSC741      232   $3,036.88
# 17                  ARLVA727      514   $8,105.78
# 18                  COLSC813      189   $2,233.98
# 19                  COLSC533      621   $6,967.62
# 20                  CHEMD887      461   $3,227.00
# 21                  PINNC615      146   $1,753.46
# 22                  COLSC133      261   $3,455.64
# 23                  CHEMD365      602   $6,062.14
# 24                  COLSC201      225     $974.25
# 25                  COLSC481      972  $12,762.36
# 26                  PINNC547      362   $6,132.28
# 27                  CHEMD323      588   $5,780.04
# 28                  ARLVA876      381   $5,695.95
# 29                  CHEMD584      782  $15,671.28

# %% [markdown]
# ## Guardar archivos

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
# Para guardar un archivo en csv se usa "to_csv", declarando el combre que va a tener el archivo
animals.to_csv('cows_and_goats.csv')
